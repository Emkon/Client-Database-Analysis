# %%
import numpy as np
import pandas as pd
#import matplotlib.pyplot as plt

# %%
# The goal of the analysis
# 1. Find the top products
#2. Find the top clients
# 3. Revenue

# %%
customers = pd.read_csv("customers.csv")

# %%
products = pd.read_csv("products.csv")

# %%
ratings = pd.read_csv("ratings.csv")

# %%
orders = pd.read_csv("orders.csv")

# %% [markdown]
# ### Converting order_date in the order dataset to datetime format

# %%
orders
# Out:
#      order_id  customer_id  product_id                  order_date  quantity
# 0           1           66          38  2023-08-09 08:39:23.971834         4
# 1           2           10          29  2023-09-08 08:39:23.971834         4
# 2           3           58           9  2023-07-29 08:39:23.971834         3
# 3           4           33          44  2023-09-13 08:39:23.971834         4
# 4           5           32          47  2023-07-24 08:39:23.971834         2
# ..        ...          ...         ...                         ...       ...
# 995       996           30          42  2023-08-15 08:39:23.971834         4
# 996       997            3          16  2023-09-11 08:39:23.971834         2
# 997       998           84          29  2023-09-05 08:39:23.971834         2
# 998       999           77          43  2023-08-13 08:39:23.971834         4
# 999      1000           19          32  2023-09-07 08:39:23.971834         3
#
# [1000 rows x 5 columns]

# %%
orders["order_date"] = pd.to_datetime(orders["order_date"])

# %%
orders
# Out:
#      order_id  customer_id  product_id                 order_date  quantity
# 0           1           66          38 2023-08-09 08:39:23.971834         4
# 1           2           10          29 2023-09-08 08:39:23.971834         4
# 2           3           58           9 2023-07-29 08:39:23.971834         3
# 3           4           33          44 2023-09-13 08:39:23.971834         4
# 4           5           32          47 2023-07-24 08:39:23.971834         2
# ..        ...          ...         ...                        ...       ...
# 995       996           30          42 2023-08-15 08:39:23.971834         4
# 996       997            3          16 2023-09-11 08:39:23.971834         2
# 997       998           84          29 2023-09-05 08:39:23.971834         2
# 998       999           77          43 2023-08-13 08:39:23.971834         4
# 999      1000           19          32 2023-09-07 08:39:23.971834         3
#
# [1000 rows x 5 columns]

# %% [markdown]
# #### Merging the order and the customer dataset

# %%
merged_data = orders.merge(products, on="product_id").merge(customers, on="customer_id")

# %%
merged_data
# Out:
#      order_id  customer_id  product_id                 order_date  quantity  \
# 0           1           66          38 2023-08-09 08:39:23.971834         4
# 1         429           66          38 2023-09-10 08:39:23.971834         3
# 2         101           66          47 2023-08-26 08:39:23.971834         1
# 3         563           66          26 2023-09-02 08:39:23.971834         2
# 4         540           66          11 2023-08-18 08:39:23.971834         2
# ..        ...          ...         ...                        ...       ...
# 995       697           83          22 2023-08-22 08:39:23.971834         3
# 996       193           38          19 2023-09-15 08:39:23.971834         4
# 997       911           38          32 2023-08-06 08:39:23.971834         1
# 998       738           38           6 2023-09-08 08:39:23.971834         4
# 999       747           38           4 2023-09-09 08:39:23.971834         3
#
# ...

# %%
product_performance = merged_data.groupby("product_name").agg({"price":"sum", "quantity":"sum"}).reset_index()

# %%
product_performance
# Out:
#                product_name  price  quantity
# 0          Askvoll Wardrobe   3864        50
# 1   Bekant Conference Table  11907        62
# 2            Bernhard Chair   1280        36
# 3            Bestå TV Bench  18400        46
# 4            Billy Bookcase   5453        40
# 5       Brimnes Bed Storage  23190        77
# 6             Docksta Table  18039        54
# 7               Ektorp Sofa  14574        59
# 8        Fjälla Storage Box  18734        44
# 9               Fredde Desk  18854        46
# 10         Gronlid Armchair  12223        43
# 11         Hektar Work Lamp  10491        32
# 12            Hemnes Daybed  16900        53
# 13         Ingolf Bar Stool   9135        39
# 14             Ivar Cabinet  17862        55
# 15     Kallax Shelving Unit  15393        51
# 16             Kivik Chaise   9260        22
# 17         Klippan Loveseat  12141        52
# 18          Koppang Dresser  14535        48
# 19          Lack Side Table  13623        39
# ...

# %%
top_products_revenue = product_performance.sort_values(by="price", ascending=False)
top_products_units = product_performance.sort_values(by="quantity", ascending=False)


top_products_revenue
# Out:
#                product_name  price  quantity
# 5       Brimnes Bed Storage  23190        77
# 41         Småstad Wardrobe  20874        52
# 37             Råskog Stool  20520        59
# 9               Fredde Desk  18854        46
# 8        Fjälla Storage Box  18734        44
# 3            Bestå TV Bench  18400        46
# 27             Nockeby Sofa  18101        58
# 6             Docksta Table  18039        54
# 14             Ivar Cabinet  17862        55
# 12            Hemnes Daybed  16900        53
# 36     Rugveda Coffee Table  16065        46
# 49       Valje Wall Cabinet  16056        60
# 47      Terje Folding Chair  15466        44
# 15     Kallax Shelving Unit  15393        51
# 22    Mackapar Shoe Storage  15114        80
# 7               Ektorp Sofa  14574        59
# 18          Koppang Dresser  14535        48
# 30        Pjatteryd Picture  14300        41
# 21         Lommarp Bookcase  13760        41
# 31           Poäng Armchair  13656        63
# ...

# %%
top_products_units
# Out:
#                product_name  price  quantity
# 22    Mackapar Shoe Storage  15114        80
# 5       Brimnes Bed Storage  23190        77
# 31           Poäng Armchair  13656        63
# 45   Söderhamn Sofa Section  11691        63
# 1   Bekant Conference Table  11907        62
# 24    Melltorp Dining Table  10332        62
# 43     Strandmon Wing Chair   2050        61
# 49       Valje Wall Cabinet  16056        60
# 7               Ektorp Sofa  14574        59
# 37             Råskog Stool  20520        59
# 28     Nordli Chest Drawers  12342        59
# 27             Nockeby Sofa  18101        58
# 14             Ivar Cabinet  17862        55
# 6             Docksta Table  18039        54
# 12            Hemnes Daybed  16900        53
# 38   Sinnerlig Pendant Lamp  11590        52
# 41         Småstad Wardrobe  20874        52
# 17         Klippan Loveseat  12141        52
# 15     Kallax Shelving Unit  15393        51
# 26         Mörbylånga Table   5364        50
# ...

# %%
top_products_units = top_products_units.rename(columns={"price":"price(£)"})

# %%
top_products_units
# Out:
#                product_name  price(£)  quantity
# 22    Mackapar Shoe Storage     15114        80
# 5       Brimnes Bed Storage     23190        77
# 31           Poäng Armchair     13656        63
# 45   Söderhamn Sofa Section     11691        63
# 1   Bekant Conference Table     11907        62
# 24    Melltorp Dining Table     10332        62
# 43     Strandmon Wing Chair      2050        61
# 49       Valje Wall Cabinet     16056        60
# 7               Ektorp Sofa     14574        59
# 37             Råskog Stool     20520        59
# 28     Nordli Chest Drawers     12342        59
# 27             Nockeby Sofa     18101        58
# 14             Ivar Cabinet     17862        55
# 6             Docksta Table     18039        54
# 12            Hemnes Daybed     16900        53
# 38   Sinnerlig Pendant Lamp     11590        52
# 41         Småstad Wardrobe     20874        52
# 17         Klippan Loveseat     12141        52
# 15     Kallax Shelving Unit     15393        51
# ...

# %%
import datetime as dt

# %%
#filtering orders for the last month
last_month = merged_data[merged_data["order_date"].dt.month == merged_data["order_date"].dt.month.max()]

#calculating the total purchase amount for each customer in the last month
top_clients_last_month = last_month.groupby("name").agg({"price":"sum"}).reset_index()

top_clients_last_month = top_clients_last_month.sort_values(by="price", ascending=False)

# %%
top_clients_last_month
# Out:
#            name  price
# 0    Customer_1   5466
# 26  Customer_33   4476
# 38  Customer_44   4259
# 46  Customer_52   4236
# 71  Customer_76   3981
# ..          ...    ...
# 78  Customer_82    187
# 3   Customer_11    184
# 4   Customer_12    176
# 56  Customer_61    157
# 76  Customer_80     97
#
# [96 rows x 2 columns]

# %%
#Notably, in the last one month, customer_1 has more purchase than every other customer. 
# But we needd to find if this is a loyal customer to the brand

# %%
# We'll do so by performing customer segmentation on the data using the RFM method

# %% [markdown]
# ### What is RFM method?

# %%
#RFM analysis, which stands for Recency, Frequency, and Monetary value, is a technique that helps marketers identify..
#...their most valuable customers.

# %%
latest_date = merged_data["order_date"].max() + dt.timedelta(days=1)

# %% [markdown]
# ### Calculating the RFM values

# %%
rfm = merged_data.groupby("customer_id").agg({
    "order_date": lambda x: (latest_date - x.max()).days,
    "order_id":"count", 
    "price":"sum"
}).rename(columns={
    "order_date":"recency",
    "order_id":"frequency",
    "price":"monetary"
})

# %% [markdown]
# ### Assigning scores from 1 to 5 for each metric

# %%
rfm["recency_score"] = pd.qcut(rfm["recency"], 5, labels=[5,4,3,2,1])
rfm["frequency_score"] = pd.qcut(rfm["frequency"], 5, labels=[1,2,3,4,5])
rfm["monetary_score"] = pd.qcut(rfm["monetary"], 5, labels = [1,2,3,4,5])

# %%
#combine scores

# %%
rfm["rfm_score"] = rfm["recency_score"].astype(str) + rfm["frequency_score"].astype(str) + rfm["monetary_score"].astype(str)

rfm_sorted = rfm.sort_values(by=["rfm_score"], ascending=False)

# %%
rfm_sorted
# Out:
#              recency  frequency  monetary recency_score frequency_score  \
# customer_id
# 1                  1         18     12106             5               5
# 29                 1         14      9225             5               5
# 52                 1         16      8862             5               5
# 47                 2         14      7385             5               5
# 33                 2         15      8769             5               5
# ...              ...        ...       ...           ...             ...
# 87                21          7      3502             1               1
# 79                16          3      2029             1               1
# 46                29          4      2488             1               1
# 13                12          6      3657             1               1
# 58                15          5      2324             1               1
#
#             monetary_score rfm_score
# customer_id
# 1                        5       555
# ...

# %%
ratings
# Out:
#      customer_id  product_id  rating
# 0             83          31       2
# 1             73          38       3
# 2              2          18       1
# 3            100          39       3
# 4             47          16       1
# ..           ...         ...     ...
# 395           92          50       5
# 396           35          26       2
# 397           60          13       5
# 398           22           7       5
# 399           64          48       1
#
# [400 rows x 3 columns]

# %% [markdown]
# #### Identifying the top reviewed product

# %%
top_reviewed_products = ratings.groupby("product_id").size().reset_index(name="num_reviews")
top_reviewed_products = top_reviewed_products.merge(products, on="product_id")
top_reviewed_products = top_reviewed_products.sort_values(by="num_reviews", ascending=False)

# %%
top_reviewed_products
# Out:
#     product_id  num_reviews             product_name  price           category
# 11          12           16           Raskog Trolley    764  Storage Solutions
# 37          38           14  Bekant Conference Table    441     Tables & Desks
# 6            7           13          Lack Side Table    717     Tables & Desks
# 30          31           12             Nockeby Sofa    787  Sofas & Armchairs
# 44          45           11         Hektar Work Lamp    807           Lighting
# 31          32           11             Kivik Chaise    926  Sofas & Armchairs
# 27          28           11         Tarva Nightstand    547              Decor
# 26          27           11             Ivar Cabinet    687  Storage Solutions
# 16          17           11   Sinnerlig Pendant Lamp    610           Lighting
# 29          30           11     Strandmon Wing Chair     82             Chairs
# 8            9           11               Micke Desk     19     Tables & Desks
# ...

# %%
reviews_per_customer = ratings.groupby("customer_id").size()
avg_reviews_per_customer = reviews_per_customer.mean()

# %%
# to have the average rating included in our result we will simply write

# %%
product_reviews = ratings.groupby("product_id").agg({
    "rating": ["count", "mean"]
}).reset_index()

#flattening the column header for easier reference
product_reviews.columns = ["product_id", "num_reviews", "avg_rating"]

# merging with the product dataset to get the product names
product_reviews = product_reviews.merge(products, on="product_id")

top_reviewed_with_avg_rating = product_reviews.sort_values(by="avg_rating", ascending=False)

top_reviewed_with_avg_rating
# Out:
#     product_id  num_reviews  avg_rating             product_name  price  \
# 24          25            2    4.500000       Rens Sheepskin Rug    610
# 19          20            6    4.166667        Pjatteryd Picture    715
# 3            4           10    3.900000           Malm Bed Frame    202
# 43          44            7    3.857143          Koppang Dresser    765
# 21          22            5    3.800000     Nordli Chest Drawers    561
# 13          14           10    3.800000         Ingolf Bar Stool    609
# 36          37            9    3.777778              Fredde Desk    857
# 46          47            4    3.750000          Nymö Lamp Shade    157
# 42          43            3    3.666667      Sjöpenna Floor Lamp    187
# 49          50            9    3.666667         Mörbylånga Table    298
# 5            6           11    3.636364      Brimnes Bed Storage    773
# 22          23            5    3.600000           Stuva Loft Bed     97
# ...
